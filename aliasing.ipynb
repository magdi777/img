# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def filtro_antialiasing(imagen, tamanio_kernel):
    # Aplicamos suavizado Gaussiano como antialiasing
    imagen_suavizada = cv2.GaussianBlur(imagen, (tamanio_kernel, tamanio_kernel), 0)
    return imagen_suavizada

# Cargar imagen
imagen = cv2.imread('alis1.jpg')
img_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# Aplicar el filtro antialiasing
img_antialias = filtro_antialiasing(img_rgb, 5)

# Mostrar resultados
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title("Original")

plt.subplot(1, 2, 2)
plt.imshow(img_antialias)
plt.title("Con Antialiasing (Gaussiano)")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def filtro_antialiasing(imagen, tamanio_kernel):
    # Aplicamos suavizado Gaussiano como antialiasing
    imagen_suavizada = cv2.GaussianBlur(imagen, (tamanio_kernel, tamanio_kernel), 0)
    return imagen_suavizada

# Cargar imagen
imagen = cv2.imread('alis2.jpg')
img_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# Aplicar el filtro antialiasing
img_antialias = filtro_antialiasing(img_rgb, 5)

# Mostrar resultados
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title("Original")

plt.subplot(1, 2, 2)
plt.imshow(img_antialias)
plt.title("Con Antialiasing (Gaussiano)")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def filtro_antialiasing(imagen, tamanio_kernel):
    # Aplicamos suavizado Gaussiano como antialiasing
    imagen_suavizada = cv2.GaussianBlur(imagen, (tamanio_kernel, tamanio_kernel), 0)
    return imagen_suavizada

# Cargar imagen
imagen = cv2.imread('alis3.jpg')
img_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# Aplicar el filtro antialiasing
img_antialias = filtro_antialiasing(img_rgb, 5)

# Mostrar resultados
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title("Original")

plt.subplot(1, 2, 2)
plt.imshow(img_antialias)
plt.title("Con Antialiasing (Gaussiano)")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('alis1.jpg', cv2.IMREAD_GRAYSCALE)

kernel_diagonal = np.array([
    [-2, -1,  0],
    [-1,  0,  1],
    [ 0,  1,  2]
])

img_diagonal = cv2.filter2D(img, -1, kernel_diagonal)
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Imagen Original")
plt.imshow(img, cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title("Convolución Diagonal")
plt.imshow(img_diagonal, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('alis2.jpg', cv2.IMREAD_GRAYSCALE)

kernel_diagonal = np.array([
    [-2, -1,  0],
    [-1,  0,  1],
    [ 0,  1,  2]
])

img_diagonal = cv2.filter2D(img, -1, kernel_diagonal)
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Imagen Original")
plt.imshow(img, cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title("Convolución Diagonal")
plt.imshow(img_diagonal, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('alis3.jpg', cv2.IMREAD_GRAYSCALE)

kernel_diagonal = np.array([
    [-2, -1,  0],
    [-1,  0,  1],
    [ 0,  1,  2]
])

img_diagonal = cv2.filter2D(img, -1, kernel_diagonal)
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Imagen Original")
plt.imshow(img, cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title("Convolución Diagonal")
plt.imshow(img_diagonal, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()
